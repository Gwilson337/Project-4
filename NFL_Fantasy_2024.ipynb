# %% [markdown]
# <a href="https://colab.research.google.com/github/Gwilson337/Project-4/blob/main/NFL_Fantasy_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import random
import numpy as np

# %%
#Create file paths
csv_path1 = Path("/content/FantasyPros_2019.csv")
csv_path2 = Path("/content/FantasyPros_2020.csv")
csv_path3 = Path("/content/FantasyPros_2021.csv")
csv_path4 = Path("/content/FantasyPros_2022.csv")
csv_path5 = Path("/content/FantasyPros_2023.csv")

# Create DataFrames
df1 = pd.read_csv(csv_path1)
df2 = pd.read_csv(csv_path2)
df3 = pd.read_csv(csv_path3)
df4 = pd.read_csv(csv_path4)
df5 = pd.read_csv(csv_path5)

# #Join DataFrames
# all_df = pd.concat([df1, df2, df3, df4, df5], axis = 1)
# all_df.head()
# # all_df.shape

# %%
df1 = df1[["#", "Player", "Pos", "AVG", "TTL"]].rename(columns={"#" : "2019_Rank", "AVG" : "2019_AVG", "TTL" : "2019_TTL"})
df2 = df2[["#", "Player", "AVG", "TTL"]].rename(columns={"#" : "2020_Rank", "AVG" : "2020_AVG", "TTL" : "2020_TTL"})
df3 = df3[["#", "Player", "AVG", "TTL"]].rename(columns={"#" : "2021_Rank", "AVG" : "2021_AVG", "TTL" : "2021_TTL"})
df4 = df4[["#", "Player", "AVG", "TTL"]].rename(columns={"#" : "2022_Rank", "AVG" : "2022_AVG", "TTL" : "2022_TTL"})
df5 = df5[["#", "Player", "AVG", "TTL"]].rename(columns={"#" : "2023_Rank", "AVG" : "2023_AVG", "TTL" : "2023_TTL"})

all_df = pd.merge(df1, df2, on="Player", how="inner")
all_df = pd.merge(all_df, df3, on="Player", how="inner")
all_df = pd.merge(all_df, df4, on="Player", how="inner")
all_df = pd.merge(all_df, df5, on="Player", how="inner")

all_df
# Out:
#      2019_Rank               Player Pos  2019_AVG  2019_TTL  2020_Rank  \
# 0            1        Lamar Jackson  QB      28.1     421.7         10
# 1            2  Christian McCaffrey  RB      22.2     355.2        222
# 2            3         Dak Prescott  QB      21.8     348.8         91
# 3            4       Jameis Winston  QB      21.0     335.4        573
# 4            5       Russell Wilson  QB      20.9     333.6          6
# ..         ...                  ...  ..       ...       ...        ...
# 272        565       Keith Kirkwood  WR       0.0       0.0        597
# 273        642            Tim Boyle  QB       0.0      -0.1        717
# 274        643         Nick Mullens  QB      -0.2      -0.3        109
# 275        648  Ray-Ray McCloud III  WR      -0.3      -2.0        466
# 276        651        Corey Clement  RB      -1.0      -4.0        436
#
#      2020_AVG  2020_TTL  2021_Rank  2021_AVG  2021_TTL  2022_Rank  2022_AVG  \
# 0        22.8     341.8         19      21.1     253.0         19      20.3
# 1        24.5      73.4        191      12.9      90.5         14      16.0
# 2        27.7     138.6          8      20.7     330.6         28      17.8
# 3         0.6       2.4        127      17.2     120.4        292      16.3
# 4        23.3     372.8         20      17.8     248.8         22      15.7
# ..        ...       ...        ...       ...       ...        ...       ...
# 272       1.3       1.3        602       0.6       1.7        593       0.6
# 273      -0.1      -0.9        377       7.6      30.3        718      -0.9
# 274      12.8     128.3        498       9.9       9.9        468       3.2
# 275       0.8      12.2        388       1.7      27.2        311       2.6
# 276       1.1      16.0        406       2.1      22.9        436       3.4
#
#      2022_TTL  2023_Rank  2023_AVG  2023_TTL
# 0       243.1          4      21.1     338.2
# 1       271.4          6      20.3     324.3
# 2       213.6          3      20.7     351.8
# 3        48.9        438       2.1      15.0
# 4       235.8         16      17.7     264.9
# ..        ...        ...       ...       ...
# 272       1.8        478       0.8       9.7
# 273      -0.9        440       5.0      14.9
# 274      12.8        218      14.9      74.7
# 275      44.1        423       1.4      16.5
# 276      16.9        604       0.0       0.0
#
# [277 rows x 17 columns]

# %%
# Check for missing values
all_df.isnull().value_counts()
# Out:
# 2019_Rank  Player  Pos    2019_AVG  2019_TTL  2020_Rank  2020_AVG  2020_TTL  2021_Rank  2021_AVG  2021_TTL  2022_Rank  2022_AVG  2022_TTL  2023_Rank  2023_AVG  2023_TTL
# False      False   False  False     False     False      False     False     False      False     False     False      False     False     False      False     False       277
# Name: count, dtype: int64

# %%
# Check data types
all_df.dtypes
# Out:
# 2019_Rank      int64
# Player        object
# Pos           object
# 2019_AVG     float64
# 2019_TTL     float64
# 2020_Rank      int64
# 2020_AVG     float64
# 2020_TTL     float64
# 2021_Rank      int64
# 2021_AVG     float64
# 2021_TTL     float64
# 2022_Rank      int64
# 2022_AVG     float64
# 2022_TTL     float64
# 2023_Rank      int64
# 2023_AVG     float64
# 2023_TTL     float64
# dtype: object

# %%
# Change rank column to float and verify
all_df[["2019_Rank", "2020_Rank", "2021_Rank", "2022_Rank", "2023_Rank"]] = all_df[["2019_Rank", "2020_Rank", "2021_Rank", "2022_Rank", "2023_Rank"]].astype("float")
all_df.dtypes
# Out:
# 2019_Rank    float64
# Player        object
# Pos           object
# 2019_AVG     float64
# 2019_TTL     float64
# 2020_Rank    float64
# 2020_AVG     float64
# 2020_TTL     float64
# 2021_Rank    float64
# 2021_AVG     float64
# 2021_TTL     float64
# 2022_Rank    float64
# 2022_AVG     float64
# 2022_TTL     float64
# 2023_Rank    float64
# 2023_AVG     float64
# 2023_TTL     float64
# dtype: object

# %%
# Set player name as index
all_df = all_df.set_index(["Player", "Pos"])
all_df.head()
# Out:
#                          2019_Rank  2019_AVG  2019_TTL  2020_Rank  2020_AVG  \
# Player              Pos
# Lamar Jackson       QB         1.0      28.1     421.7       10.0      22.8
# Christian McCaffrey RB         2.0      22.2     355.2      222.0      24.5
# Dak Prescott        QB         3.0      21.8     348.8       91.0      27.7
# Jameis Winston      QB         4.0      21.0     335.4      573.0       0.6
# Russell Wilson      QB         5.0      20.9     333.6        6.0      23.3
#
#                          2020_TTL  2021_Rank  2021_AVG  2021_TTL  2022_Rank  \
# Player              Pos
# Lamar Jackson       QB      341.8       19.0      21.1     253.0       19.0
# Christian McCaffrey RB       73.4      191.0      12.9      90.5       14.0
# Dak Prescott        QB      138.6        8.0      20.7     330.6       28.0
# Jameis Winston      QB        2.4      127.0      17.2     120.4      292.0
# Russell Wilson      QB      372.8       20.0      17.8     248.8       22.0
#
#                          2022_AVG  2022_TTL  2023_Rank  2023_AVG  2023_TTL
# Player              Pos
# Lamar Jackson       QB       20.3     243.1        4.0      21.1     338.2
# Christian McCaffrey RB       16.0     271.4        6.0      20.3     324.3
# Dak Prescott        QB       17.8     213.6        3.0      20.7     351.8
# Jameis Winston      QB       16.3      48.9      438.0       2.1      15.0
# Russell Wilson      QB       15.7     235.8       16.0      17.7     264.9

# %%
# Get list of columns to store as features
all_df.columns
# Out:
# Index(['2019_Rank', '2019_AVG', '2019_TTL', '2020_Rank', '2020_AVG',
#        '2020_TTL', '2021_Rank', '2021_AVG', '2021_TTL', '2022_Rank',
#        '2022_AVG', '2022_TTL', '2023_Rank', '2023_AVG', '2023_TTL'],
#       dtype='object')

# %%
# Drop position column and verify
# all_df = all_df.drop(columns="Pos")
# all_df.head()

# %%
# Separate features from label
labelName = ["2023_TTL"]
featureNames = ['2019_Rank', '2019_AVG', '2019_TTL', '2020_Rank', '2020_AVG',
       '2020_TTL', '2021_Rank', '2021_AVG', '2021_TTL', '2022_Rank',
       '2022_AVG', '2022_TTL', '2023_Rank', '2023_AVG']
dfFeatures = all_df[featureNames]
dfFeatures.head()
# Out:
#                          2019_Rank  2019_AVG  2019_TTL  2020_Rank  2020_AVG  \
# Player              Pos
# Lamar Jackson       QB         1.0      28.1     421.7       10.0      22.8
# Christian McCaffrey RB         2.0      22.2     355.2      222.0      24.5
# Dak Prescott        QB         3.0      21.8     348.8       91.0      27.7
# Jameis Winston      QB         4.0      21.0     335.4      573.0       0.6
# Russell Wilson      QB         5.0      20.9     333.6        6.0      23.3
#
#                          2020_TTL  2021_Rank  2021_AVG  2021_TTL  2022_Rank  \
# Player              Pos
# Lamar Jackson       QB      341.8       19.0      21.1     253.0       19.0
# Christian McCaffrey RB       73.4      191.0      12.9      90.5       14.0
# Dak Prescott        QB      138.6        8.0      20.7     330.6       28.0
# Jameis Winston      QB        2.4      127.0      17.2     120.4      292.0
# Russell Wilson      QB      372.8       20.0      17.8     248.8       22.0
#
#                          2022_AVG  2022_TTL  2023_Rank  2023_AVG
# Player              Pos
# Lamar Jackson       QB       20.3     243.1        4.0      21.1
# Christian McCaffrey RB       16.0     271.4        6.0      20.3
# Dak Prescott        QB       17.8     213.6        3.0      20.7
# Jameis Winston      QB       16.3      48.9      438.0       2.1
# Russell Wilson      QB       15.7     235.8       16.0      17.7

# %%
# View testing data
dfLabels = all_df[labelName]
dfLabels.head()
# Out:
#                          2023_TTL
# Player              Pos
# Lamar Jackson       QB      338.2
# Christian McCaffrey RB      324.3
# Dak Prescott        QB      351.8
# Jameis Winston      QB       15.0
# Russell Wilson      QB      264.9

# %%
# Flatten arrays
labels = np.array(dfLabels).ravel()
features = np.array(dfFeatures)

# %%
# Split data into training and testing sets
train, test, trainLabels, testLabels = train_test_split(features, labels, test_size=(0.10), random_state=75)

# %%
# Create RandomForest instance
rf = RandomForestRegressor(random_state=75)

# %%
# Fit the model
rf.fit(train, trainLabels)
# Out:
# RandomForestRegressor(random_state=75)

# %%
# Create model prediction
rfPred = rf.predict(features)

# %%
print('The model score is:', rf.score(features,labels))
# Out:
# The model score is: 0.9992349153076943

# %%
# Create new dataframe and add column
fantasy_2024 = all_df[["2023_TTL"]]
fantasy_2024["2024_Points_Predicted"] = rfPred
# Out:
# <ipython-input-19-5403bc360eec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fantasy_2024["2024_Points_Predicted"] = rfPred

# %%
# View prediction model dataframe
fantasy_2024.head()
# Out:
#                          2023_TTL  2024_Points_Predicted
# Player              Pos
# Lamar Jackson       QB      338.2                337.307
# Christian McCaffrey RB      324.3                329.691
# Dak Prescott        QB      351.8                347.200
# Jameis Winston      QB       15.0                 14.764
# Russell Wilson      QB      264.9                272.209

# %%
# View in descending order
fantasy_2024.sort_values("2024_Points_Predicted", ascending=False).head(60)
# Out:
#                          2023_TTL  2024_Points_Predicted
# Player              Pos
# Josh Allen          QB      410.6                380.975
# Dak Prescott        QB      351.8                347.200
# Lamar Jackson       QB      338.2                337.307
# Christian McCaffrey RB      324.3                329.691
# Patrick Mahomes II  QB      294.2                300.454
# Jared Goff          QB      303.1                296.569
# Baker Mayfield      QB      284.1                282.270
# Russell Wilson      QB      264.9                272.209
# Matthew Stafford    QB      254.1                259.641
# Tyreek Hill         WR      257.4                255.337
# Derek Carr          QB      249.1                252.043
# Raheem Mostert      RB      242.7                245.493
# Geno Smith          QB      235.3                236.748
# Derrick Henry       RB      218.7                222.545
# Joe Mixon           RB      215.0                218.947
# Gardner Minshew II  QB      205.2                206.296
# Mike Evans          WR      203.5                202.088
# David Montgomery    RB      191.2                195.056
# DJ Moore            WR      190.5                192.108
# A.J. Brown          WR      183.6                184.547
# Deebo Samuel        WR      183.7                183.771
# Saquon Barkley      RB      182.2                183.378
# Dallas Cowboys      DST     178.0                177.782
# James Conner        RB      174.5                175.567
# Baltimore Ravens    DST     174.0                173.167
# Keenan Allen        WR      170.9                172.743
# Tony Pollard        RB      167.6                168.786
# Stefon Diggs        WR      166.8                167.743
# Davante Adams       WR      162.4                162.116
# Justin Tucker       K       160.0                159.916
# DK Metcalf          WR      159.4                159.342
# Alvin Kamara        RB      158.0                159.117
# Buffalo Bills       DST     159.0                158.978
# Jason Myers         K       158.0                158.064
# Cairo Santos        K       158.0                157.864
# Matt Gay            K       157.0                157.063
# Jake Elliott        K       156.0                156.110
# Amari Cooper        WR      155.0                155.898
# Kirk Cousins        QB      154.7                155.669
# New York Jets       DST     154.0                154.110
# Harrison Butker     K       154.0                154.091
# Cleveland Browns    DST     153.0                153.088
# Kyler Murray        QB      151.4                152.790
# Miami Dolphins      DST     152.0                152.614
# Jakobi Meyers       WR      147.6                147.678
# DeAndre Hopkins     WR      148.6                147.518
# Dustin Hopkins      K       149.0                147.403
# Las Vegas Raiders   DST     146.0                146.388
# Jason Sanders       K       146.0                145.929
# Brandon McManus     K       146.0                145.505
# Josh Jacobs         RB      144.1                143.649
# Pittsburgh Steelers DST     143.0                143.376
# New Orleans Saints  DST     143.0                143.231
# Greg Zuerlein       K       143.0                143.228
# San Francisco 49ers DST     141.0                140.037
# Indianapolis Colts  DST     139.0                138.872
# George Kittle       TE      138.2                138.483
# Younghoe Koo        K       138.0                138.038
# Devin Singletary    RB      137.3                137.271
# Chase McLaughlin    K       136.0                136.199
